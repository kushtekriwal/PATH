# %%
import pandas as pd
import numpy as np

# %%
lookup = pd.read_csv("C:/Users/kusht/Downloads/Country Lookup.csv",encoding = 'unicode_escape')

# %%
lookup
# Out:
#                      Countdown Country  Countdown Indicator GHO Country Code  \
# 0                          Afghanistan                    1              AFG
# 1                              Algeria                    1              DZA
# 2                               Angola                    1              AGO
# 3                           Azerbaijan                    1              AZE
# 4                           Bangladesh                    1              BGD
# 5                                Benin                    1              BEN
# 6                               Bhutan                    1              BTN
# 7     Bolivia (Plurinational State of)                    1              BOL
# 8                             Botswana                    1              BWA
# 9                         Burkina Faso                    1              BFA
# 10                             Burundi                    1              BDI
# ...

# %%
enap2 = pd.read_csv("C:/Users/kusht/Downloads/ENAP_Processed_v2.csv")

# %%
enap2.head()
# Out:
#        Country                                     Indicator Name  \
# 0  Afghanistan  Is Oxytocin included in the National Essential...
# 1       Angola  Is Oxytocin included in the National Essential...
# 2    Argentina  Is Oxytocin included in the National Essential...
# 3      Armenia  Is Oxytocin included in the National Essential...
# 4   Azerbaijan  Is Oxytocin included in the National Essential...
#
#   Indicator Value (Text)  Indicator Value (Numeric)
# 0                    Yes                        1.0
# 1                    Yes                        1.0
# 2                    Yes                        1.0
# 3                    Yes                        1.0
# 4                    Yes                        1.0

# %%
lookup
# Out:
#                      Countdown Country  Countdown Indicator GHO Country Code  \
# 0                          Afghanistan                    1              AFG
# 1                              Algeria                    1              DZA
# 2                               Angola                    1              AGO
# 3                           Azerbaijan                    1              AZE
# 4                           Bangladesh                    1              BGD
# 5                                Benin                    1              BEN
# 6                               Bhutan                    1              BTN
# 7     Bolivia (Plurinational State of)                    1              BOL
# 8                             Botswana                    1              BWA
# 9                         Burkina Faso                    1              BFA
# 10                             Burundi                    1              BDI
# ...

# %%
enapcountries =enap2['Country'].unique()

# %%
len(enapcountries)
# Out:
# 65

# %%
for i in enapcountries:
    if i not in np.array(lookup['GHO Country']):
        print(i)
# Out:
# Congo (Democratic Republic of the)
# Korea (Democratic People's Republic of)
# Swaziland
# Tanzania

# %%
enap2 = enap2[enap2['Country'] != 'Vietnam']

# %%
for idx, i in enumerate(enap2['Country']):
    if i == "Venezuela":
        enap2['Country'].loc[idx] = 'Venezuela (Bolivarian Republic of)'
# Out:
# C:\Users\kusht\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
enap2
# Out:
#                                       Country  \
# 0                                 Afghanistan
# 1                                      Angola
# 4                                  Azerbaijan
# 5                                  Bangladesh
# 6                                       Benin
# 7                                      Bhutan
# 8                                Burkina Faso
# 9                                     Burundi
# 10                                   Cameroon
# 12                   Central African Republic
# 13                                       Chad
# 15                                    Comoros
# 16                                      Congo
# 17         Congo (Democratic Republic of the)
# 18                              Côte d'Ivoire
# 19                                   Djibouti
# 22                          Equatorial Guinea
# 23                                    Eritrea
# 24                                   Ethiopia
# ...

# %%
lookup.iloc[77]
# Out:
# Countdown Country      Venezuela (Bolivarian Republic of)
# Countdown Indicator                                     1
# GHO Country Code                                      VEN
# GHO Country            Venezuela (Bolivarian Republic of)
# DHS Country Code                                      NaN
# DHS Country                                           NaN
# ENAP Country                                        Syria
# Name: 77, dtype: object

# %%
from IPython.display import FileLink, FileLinks

enap2.to_csv('C:/Users/kusht/Downloads/ENAP_Processed_v3.csv', index=False)

# %%
lookup['ENAP Country'] = enap2['Country']

# %%
lookup
# Out:
#                      Countdown Country  Countdown Indicator GHO Country Code  \
# 0                          Afghanistan                    1              AFG
# 1                              Algeria                    1              DZA
# 2                               Angola                    1              AGO
# 3                           Azerbaijan                    1              AZE
# 4                           Bangladesh                    1              BGD
# 5                                Benin                    1              BEN
# 6                               Bhutan                    1              BTN
# 7     Bolivia (Plurinational State of)                    1              BOL
# 8                             Botswana                    1              BWA
# 9                         Burkina Faso                    1              BFA
# 10                             Burundi                    1              BDI
# ...

# %%
lookup = lookup.drop('ENAP Country', axis=1)

# %%
lookup['ENAP Country'] = np.nan

# %%
for idx,i in enumerate(lookup['Countdown Country']):
    if i in np.array(enap2['Country'].unique()):
        lookup['ENAP Country'].loc[idx] = i
# Out:
# C:\Users\kusht\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
lookup
# Out:
#                      Countdown Country  Countdown Indicator GHO Country Code  \
# 0                          Afghanistan                    1              AFG
# 1                              Algeria                    1              DZA
# 2                               Angola                    1              AGO
# 3                           Azerbaijan                    1              AZE
# 4                           Bangladesh                    1              BGD
# 5                                Benin                    1              BEN
# 6                               Bhutan                    1              BTN
# 7     Bolivia (Plurinational State of)                    1              BOL
# 8                             Botswana                    1              BWA
# 9                         Burkina Faso                    1              BFA
# 10                             Burundi                    1              BDI
# ...

# %%
lookup.iloc[18]
# Out:
# Countdown Country       Côte dIvoire
# Countdown Indicator                 1
# GHO Country Code                  CIV
# GHO Country             Côte d'Ivoire
# DHS Country Code                  CI
# DHS Country            Cote d'Ivoire
# ENAP Country                      NaN
# Name: 18, dtype: object

# %%
lookup['ENAP Country'].iloc[18] = "Côte d'Ivoire"
# Out:
# C:\Users\kusht\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
from IPython.display import FileLink, FileLinks

lookup.to_csv('C:/Users/kusht/Downloads/Country Lookup_v2.csv', index=False)
