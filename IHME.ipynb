# %%
import pandas as pd
import numpy as np

# %%
ihme = pd.read_csv("C:/Users/kusht/Downloads/IHME.csv")

# %%
ihme
# Out:
#                                       Measure       Country   Sex  \
# 0                                      Deaths        Rwanda  Both
# 1                                      Deaths        Rwanda  Both
# 2                                      Deaths        Rwanda  Both
# 3                                      Deaths      Paraguay  Both
# 4                                      Deaths      Paraguay  Both
# 5                                      Deaths      Paraguay  Both
# 6                                      Deaths          Mali  Both
# 7                                      Deaths          Mali  Both
# 8                                      Deaths          Mali  Both
# 9                                      Deaths          Mali  Both
# 10                                     Deaths          Mali  Both
# 11                                     Deaths          Mali  Both
# 12                                     Deaths          Mali  Both
# ...

# %%
ihme['age_id'].unique()
# Out:
# array([22,  1,  2,  3,  4,  5, 28], dtype=int64)

# %%
ihme = ihme.drop(['measure_id', 'sex_id', 'age_id', 'cause_id', 'metric_id', 'location_id', 'upper', 'lower'], axis=1)

# %%
ihme = ihme.rename(columns={'location_name':'Country', 'sex_name':'Sex','age_name':'Age Group', 'cause_name':'Cause', 'metric_name':'Metric', 'val':'Indicator Value', 'year':'Year', 'measure_name':'Measure'})

# %%
ihmeco = ihme['Country'].unique()

# %%
lookup = pd.read_csv("C:/Users/kusht/Downloads/Country Lookup_v3.csv")

# %%
lookup
# Out:
#                      Countdown Country  Countdown Indicator GHO Country Code  \
# 0                          Afghanistan                    1              AFG
# 1                              Algeria                    1              DZA
# 2                               Angola                    1              AGO
# 3                           Azerbaijan                    1              AZE
# 4                           Bangladesh                    1              BGD
# 5                                Benin                    1              BEN
# 6                               Bhutan                    1              BTN
# 7     Bolivia (Plurinational State of)                    1              BOL
# 8                             Botswana                    1              BWA
# 9                         Burkina Faso                    1              BFA
# 10                             Burundi                    1              BDI
# ...

# %%
for i in ihme2['Country'].unique():
    if i not in np.array(lookup['Countdown Country']):
        print(i)
# Out:
# Côte d'Ivoire

# %%
ihme2 = ihme2[ihme2['Country'] != 'Hungary']

# %%
for idx, i in enumerate(ihme2['Country']):
    if i == "Cote d'Ivoire":
        ihme2['Country'].loc[idx] = 'Côte d\'Ivoire'
# Out:
# C:\Users\kusht\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
ihme2 = ihme.reset_index()

# %%
ihme2 = ihme2.drop('index', axis=1)

# %%
ihme2
# Out:
#                                       Measure       Country   Sex  \
# 0                                      Deaths        Rwanda  Both
# 1                                      Deaths        Rwanda  Both
# 2                                      Deaths        Rwanda  Both
# 3                                      Deaths      Paraguay  Both
# 4                                      Deaths      Paraguay  Both
# 5                                      Deaths      Paraguay  Both
# 6                                      Deaths          Mali  Both
# 7                                      Deaths          Mali  Both
# 8                                      Deaths          Mali  Both
# 9                                      Deaths          Mali  Both
# 10                                     Deaths          Mali  Both
# 11                                     Deaths          Mali  Both
# 12                                     Deaths          Mali  Both
# ...

# %%
for i in lookup['Countdown Country']:
    print(i)
# Out:
# Afghanistan
# Algeria
# Angola
# Azerbaijan
# Bangladesh
# Benin
# Bhutan
# Bolivia (Plurinational State of)
# Botswana
# Burkina Faso
# Burundi
# Cambodia
# Cameroon
# Central African Republic
# Chad
# Comoros
# Congo
# Congo (Democratic Republic of the)
# Côte dIvoire
# Djibouti
# Dominican Republic
# Equatorial Guinea
# Eritrea
# Ethiopia
# Gabon
# Gambia
# Ghana
# Guatemala
# Guinea
# Guinea-Bissau
# Guyana
# Haiti
# Honduras
# India
# Indonesia
# Iraq
# Jamaica
# Kenya
# Korea (Democratic People's Republic of)
# Kyrgyzstan
# Lao People's Democratic Republic
# Lesotho
# Liberia
# Madagascar
# Malawi
# Mali
# Mauritania
# Morocco
# Mozambique
# Myanmar
# Namibia
# Nepal
# Nicaragua
# Niger
# Nigeria
# Pakistan
# Panama
# Papua New Guinea
# Paraguay
# Philippines
# Rwanda
# Senegal
# Sierra Leone
# Solomon Islands
# Somalia
# South Africa
# South Sudan
# Sudan
# Suriname
# Swaziland
# Tajikistan
# Tanzania
# Timor-Leste
# Togo
# Turkmenistan
# Uganda
# Uzbekistan
# ...

# %%
from IPython.display import FileLink, FileLinks

ihme2.to_csv('~/Downloads/IHME_Processed.csv', index=False)
