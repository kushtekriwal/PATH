# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/kusht/Downloads/Merged_Data_v7.csv")

# %%
data[data['Country'] == 'Tanzania']['Data Source'].unique()
# Out:
# array(['DHS Service Provision Assesment (SPA)', 'DHS', 'ENAP', 'HMIS'],
#       dtype=object)

# %%
model = pd.read_csv("C:/Users/kusht/Downloads/saved/modelf.csv")

# %%
model[model['Country'] == 'Tanzania']
# Out:
# array(['DHS', 'ENAP', 'DHS Service Provision Assesment (SPA)', 'HMIS'],
#       dtype=object)

# %%
dhsmanual = pd.read_csv("C:/Users/kusht/Downloads/Merged_Data_v5.csv")

# %%
gl = pd.read_csv("C:/Users/kusht/Downloads/Indicator Metadata All Countries (1).csv",encoding='latin-1')

# %%
#change cote dvoire in gl
for idx, i in enumerate(gl['Country']):
    if i == 'Côte d\x92Ivoire':
        gl['Country'].loc[idx] = "Côte d'Ivoire"
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
joined_data = pd.merge(gl2, model, left_on=['Indicator Name (matched with data source)','Country'], right_on=['Indicator Name', 'Country'], how='right')

# %%
joined_data[(joined_data['Country'] == 'Malawi') & (joined_data['Data Source'] == 'HMIS')]
# Out:
#                                Accessibility Asset (drop-down)  \
# 7177   Country accessible, manual extraction               KMC
# 7178   Country accessible, manual extraction               KMC
# 7179   Country accessible, manual extraction               KMC
# 7180   Country accessible, manual extraction               KMC
# 7181   Country accessible, manual extraction   Iron-Folic Acid
# 7182   Country accessible, manual extraction             MgSo4
# 7183   Country accessible, manual extraction   Iron-Folic Acid
# 7184   Country accessible, manual extraction             MgSo4
# 7185   Country accessible, manual extraction   Iron-Folic Acid
# 7186   Country accessible, manual extraction             MgSo4
# 7187   Country accessible, manual extraction   Iron-Folic Acid
# 7188   Country accessible, manual extraction             MgSo4
# 7189   Country accessible, manual extraction   Iron-Folic Acid
# 7190   Country accessible, manual extraction             MgSo4
# ...

# %%
gl[(gl['Country'] == 'Tanzania') & (gl['Indicator Source (linked to IS sheet)'] == 'Tanzania HMIS')]
# Out:
# Empty DataFrame
# Columns: [Country, Asset (drop-down), Stage and ID (drop-down), Milestone and ID (drop-down), Priority Milestone (Yes/No), Priority Indicator? (Yes/No), Closest to coverage, Indicator Value: Asset included in policy/guidelines? (Y/N/NA) Only applies to country-specific indicators (not "All Countries")2, Direct Indicator? (yes/no), Indicator Name (matched with data source), Old Indicator Name (don't use), Indicator Definition (per source, or PATH definition if source does not define), Type of Data Source, Indicator Source (linked to IS sheet), Accessibility, Most Recent Year Available, Panel Data Available (y/n), Frequency Notes (# of years, frequency), Data Quality Considerations (representative, standardized data collection methods), Notes and Considerations]
# Index: []

# %%
ng = pd.read_excel("C:/Users/kusht/Downloads/Nigeria DHIS 2 data set_EEmodified.xlsx")

# %%
model = model.append(ng, ignore_index=True)

# %%
model
# Out:
#       Data Source       Country  Year Characteristic Category  \
# 0             DHS  Burkina Faso  1993                   Total
# 1             DHS  Burkina Faso  1993                     Sex
# 2             DHS  Burkina Faso  1993                     Sex
# 3             DHS  Burkina Faso  1993             Child's age
# 4             DHS  Burkina Faso  1993             Child's age
# 5             DHS  Burkina Faso  1993             Child's age
# 6             DHS  Burkina Faso  1993             Child's age
# 7             DHS  Burkina Faso  1993             Child's age
# 8             DHS  Burkina Faso  1993             Child's age
# 9             DHS  Burkina Faso  1993               Residence
# 10            DHS  Burkina Faso  1993               Residence
# 11            DHS  Burkina Faso  1993               Education
# 12            DHS  Burkina Faso  1993               Education
# 13            DHS  Burkina Faso  1993               Education
# ...

# %%
tz = pd.read_excel("C:/Users/kusht/Downloads/policy/Tanzania Indicator sources and metadata (1).xlsx", sheetname='Indicator Metadata')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
tz_hmis = tz[tz['Indicator Source (linked to IS sheet)'] == 'Tanzania HMIS']

# %%
tz_hmis.columns.tolist()
tz_hmis = tz_hmis.rename(columns={'Priority Milestone (Y/N)':'Priority Milestone (Yes/No)','Closest to coverage (Y/N)':'Closest to coverage','Indicator Name (as used in indicator source)':'Indicator Name (matched with data source)'})
tz_hmis = tz_hmis.drop(['Indicator Defined by Source? (yes/no)'], axis=1)

# %%
gl.columns.tolist()
gl = gl.rename(columns={ 'Indicator Value: Asset included in policy/guidelines? (Y/N/NA) Only applies to country-specific indicators (not "All Countries")2':'Indicator Value (Yes/No/NA). Asset included in policy/guidelines? Only applies to country-specific data (not "All Countries")'})
gl = gl.drop(["Old Indicator Name (don't use)"], axis=1)

# %%
gl2 = gl.append(tz_hmis, ignore_index=True)

# %%
mw = pd.read_excel("C:/Users/kusht/Downloads/policy/Malawi Indicator sources and metadata.xlsx", sheetname='Indicator Metadata')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
mw_hmis = mw[mw['Indicator Source (linked to IS sheet)'] == 'Malawi HMIS']

# %%
mw_hmis.columns.tolist()
mw_hmis = mw_hmis.rename(columns={'Priority Milestone (Y/N)':'Priority Milestone (Yes/No)','Closest to coverage (Y/N)':'Closest to coverage','Indicator Name (as used in indicator source)':'Indicator Name (matched with data source)'})
mw_hmis = mw_hmis.drop(['Indicator Defined by Source? (yes/no)'], axis=1)

# %%
gl2 = gl2.append(mw_hmis, ignore_index=True)

# %%
ng = pd.read_excel("C:/Users/kusht/Downloads/policy/Nigeria Indicator sources and metadata (2).xlsx", sheetname='Indicator Metadata')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
ng_hmis = ng[ng['Indicator Source (linked to IS sheet)'] == 'Nigeria HMIS']

# %%
ng_hmis.columns.tolist()
ng_hmis = ng_hmis.rename(columns={'Indicator Definition (per source, or PATH definition if source does not defined)':'Indicator Definition (per source, or PATH definition if source does not define)','Type of data source':'Type of Data Source','Priority Milestone (Y/N)':'Priority Milestone (Yes/No)','Closest to Coverage? (Y/N)':'Closest to coverage','Indicator Name (as used in indicator source)':'Indicator Name (matched with data source)'})
#ng_hmis = ng_hmis.drop(['Indicator Defined by Source? (yes/no)'], axis=1)

# %%
gl2 = gl2.append(ng_hmis, ignore_index=True)

# %%
ke = pd.read_excel("C:/Users/kusht/Downloads/policy/Kenya Indicator sources and metadata (1).xlsx", sheetname='Indicator Metadata')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
ke_hmis = ke[ke['Indicator Source (linked to IS sheet)'] == 'Kenya HMIS']

# %%
ke_hmis.columns.tolist()
ke_hmis = ke_hmis.rename(columns={'Indicator Name\xa0':'Indicator Name (matched with data source)','Priority Milestone (Y/N)':'Priority Milestone (Yes/No)','Closest to Coverage':'Closest to coverage','Indicator Name (as used in indicator source)':'Indicator Name (matched with data source)'})
ke_hmis = ke_hmis.drop(['Indicator Defined by Source? (yes/no)'], axis=1)

# %%
gl2 = gl2.append(ke_hmis, ignore_index=True)

# %%
#Ethiopia_ for SARA
for idx, i in enumerate(model['Country']):
    if i == 'Ethiopia ':
        model['Country'].loc[idx] = 'Ethiopia'
        #merged2['Indicator Value (Numeric)'].loc[idx] = np.nan
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
from IPython.display import FileLink, FileLinks

model.to_csv('C:/Users/kusht/Downloads/saved/modelf2.csv', index=False)

# %%
#replace joined data dhs with dhsmanual (new gl does not have new dhs data)
dhsmanual = dhsmanual[dhsmanual['Data Source'] == 'DHS']

# %%
joined_data2 = joined_data[joined_data['Data Source'] != 'DHS']

# %%
joined_data2.columns.tolist()
joined_data3 = joined_data2.rename(columns={'Asset (drop-down)':'Asset','Stage and ID (drop-down)':'Stage and ID','Milestone and ID (drop-down)':'Milestone and ID'})
joined_data3 = joined_data3.drop(['Indicator Name (matched with data source)','Indicator Source (linked to IS sheet)','Indicator Value (Yes/No/NA). Asset included in policy/guidelines? Only applies to country-specific data (not "All Countries")'],axis=1)

# %%
dhsmanual.columns.tolist()
#dhsmanual = dhsmanual.drop(['Indicator Defined by Source? (yes/no)'],axis=1)
# Out:
# ['Accessibility',
#  'Asset',
#  'Closest to coverage',
#  'Country',
#  'Data Quality Considerations (representative, standardized data collection methods)',
#  'Direct Indicator? (yes/no)',
#  'Frequency Notes (# of years, frequency)',
#  'Indicator Definition (per source, or PATH definition if source does not define)',
#  'Milestone and ID',
#  'Most Recent Year Available',
#  'Notes and Considerations',
#  'Panel Data Available (y/n)',
#  'Priority Indicator? (Yes/No)',
#  'Priority Milestone (Yes/No)',
#  'Stage and ID',
#  'Type of Data Source',
#  'Data Source',
#  'Year',
#  'Characteristic Category',
#  'Characteristic Label',
#  'Indicator Name',
#  'Indicator Value (Numeric)',
#  'Indicator Value (Text)']

# %%
joined_data4 = joined_data3.append(dhsmanual, ignore_index=True)

# %%
from IPython.display import FileLink, FileLinks

joined_data4.to_csv('C:/Users/kusht/Downloads/saved/Merged_Data_v10.csv', index=False)
