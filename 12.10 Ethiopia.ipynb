# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/Users/kusht/Downloads/saved/Merged_Data_v19.csv")

# %%
data[(data['Country'] == 'Ethiopia')]['Indicator Name'].unique()
# Out:
# array(['Is Newborn Resuscitation (ventilation bag and mask) included in the National Essential Medicines List (NEML)?',
#        'Is Chlorhexidine included in the National Essential Medicines List (NEML)?',
#        'Is Injectable Antibiotics-Gentamycin included in the National Essential Medicines List (NEML)?',
#        'Is Magnesium Sulphate included in the National Essential Medicines List (NEML)?',
#        'Is Misoprostol included in the National Essential Medicines List (NEML)?',
#        'Is Oxytocin included in the National Essential Medicines List (NEML)?',
#        'Is Injectable Antibiotics - Ampicillin/Penicillin included in the National Essential Medicines List (NEML)?',
#        'Is Antenatal Corticosteroids included in the National Essential Medicines List (NEML)?',
#        'Does the country have Logistics Mangament Information System (LMIS) for Chlorhexidine?',
#        'Does the country have Logistics Mangament Information System (LMIS) for Magnesium sulphate?',
# ...

# %%
data[(data['Country'] == 'Ethiopia') & (data['Indicator Name'] == 'Proportion of asphyxiated neonates who were resuscitated (with bag & mask)')]#['Indicator Value (Numeric)']
# Out:
#                                     Accessibility                  Asset  \
# 7767  Country accessible, automatically extracted  Newborn Resuscitation
#
#      Characteristic Category Characteristic Label Closest to coverage  \
# 7767                   Total                Total                   Y
#
#        Country  \
# 7767  Ethiopia
#
#      Data Quality Considerations (representative, standardized data collection methods)  \
# 7767                                                NaN
#
#      Data Source Direct Indicator? (yes/no)  \
# 7767        HMIS                          Y
#
#      Frequency Notes (# of years, frequency)    ...      \
# 7767                                     NaN    ...
#
#      Indicator Value (Text)                     Milestone and ID  \
# 7767                    NaN  6.8.3 - Effective Coverage Achieved
#
#      Most Recent Year Available Notes and Considerations  \
# 7767                        NaN                      NaN
#
# ...

# %%
data['Priority Indicator? (Yes/No)'].iloc[7767] = 'Y'

# %%
data['Priority Indicator? (Yes/No)'].iloc[7767]
# Out:
# nan

# %%
from IPython.display import FileLink, FileLinks

data.to_csv('C:/Users/kusht/Downloads/saved/Merged_Data_v20.csv', index=False)

# %%
data
# Out:
#                                       Accessibility                  Asset  \
# 0      Publicly accessible, automatically extracted  Newborn Resuscitation
# 1      Publicly accessible, automatically extracted  Newborn Resuscitation
# 2      Publicly accessible, automatically extracted  Newborn Resuscitation
# 3      Publicly accessible, automatically extracted  Newborn Resuscitation
# 4      Publicly accessible, automatically extracted  Newborn Resuscitation
# 5      Publicly accessible, automatically extracted  Newborn Resuscitation
# 6      Publicly accessible, automatically extracted          Chlorhexidine
# 7      Publicly accessible, automatically extracted          Chlorhexidine
# 8      Publicly accessible, automatically extracted          Chlorhexidine
# 9      Publicly accessible, automatically extracted          Chlorhexidine
# 10     Publicly accessible, automatically extracted          Chlorhexidine
# ...

# %%
data[data['Country'] == 'Burkina Faso']['Data Source'].unique()
# Out:
# array(['ENAP', 'DHS',
#        'Pharmaceutical Specialties and Generic Drugs Allowed in Burkina Faso',
#        'National policy Infant, child, adolescent and young adult health',
#        'National policy health of women and infants less than 7 days old',
#        'National policy on obstetric and neonatal care', nan,
#        'Protocoles De Santé De La Reproduction - Santé de la femme et du nouveau-né de moins de sept (7) jours (2009) ',
#        'Assessment Of Maternity Staff Training And Knowledge Of Obstetric Care In Burkina Faso: A Repeated Cross-Sectional Study',
#        'Burkina Faso National Essential Medicines List',
#        'Burkina Faso Costed Implementation Plan', 'Health Budget',
#        'CAMEG Inventory List (national medical stores)',
#        'SONU specific curriculum used for health workers training ',
#        'Use of Chlorexidine for Newborn Umbilical Cord Care ',
# ...

# %%
bf = pd.read_csv("C:/Users/kusht/Downloads/1210/Burkina Faso Indicator sources and metadata.csv",encoding='latin_1')

# %%
bf['Indicator Source (linked to IS sheet)'].unique()
# Out:
# array(['Pharmaceutical Specialties and Generic Drugs Allowed in Burkina Faso',
#        'Sante du nourrisson, de l?enfant, de l?adolescent et du jeune',
#        'Sante de la femme et du nouveau ne de moins de 7 jours',
#        'Soins obstetricaux et neonatals d?urgence', 'Qualitative',
#        'Protocoles De Sant\x82 De La Reproduction - Sant\x82 de la femme et du nouveau-n\x82 de moins de sept (7) jours (2009) ',
#        'Assessment Of Maternity Staff Training And Knowledge Of Obstetric Care In Burkina Faso: A Repeated Cross-Sectional Study',
#        'Burkina Faso National Essential Medicines List',
#        'Burkina Faso Costed Implementation Plan', 'Health Budget',
#        'CAMEG Inventory List (national medical stores)',
#        'SONU specific curriculum used for health workers training ',
#        'Use of Chlorexidine for Newborn Umbilical Cord Care ',
#        'Advice cards on the care of the newborn at home for the use of community-based health workers',
# ...
