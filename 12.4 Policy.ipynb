# %%
import pandas as pd
import numpy as np

# %%
merged = pd.read_csv("C:/Users/kusht/Downloads/saved/Merged_Data_v10.csv")

# %%
tz= pd.read_excel("C:/Users/kusht/Downloads/policy/Tanzania Indicator sources and metadata (1).xlsx", sheetname='Indicator Metadata')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
tz_policy = tz[tz['Indicator Source (linked to IS sheet)'] != 'Tanzania HMIS']

# %%
tz_policy.columns.tolist()
tz_policy = tz_policy.rename(columns={'Indicator Name (as used in indicator source)':'Indicator Name','Indicator Source (linked to IS sheet)':'Data Source','Asset (drop-down)':'Asset','Stage and ID (drop-down)':'Stage and ID','Milestone and ID (drop-down)':'Milestone and ID','Priority Milestone (Y/N)':'Priority Milestone (Yes/No)','Closest to coverage (Y/N)':'Closest to coverage','Indicator Value (Yes/No/NA). Asset included in policy/guidelines? Only applies to country-specific data (not "All Countries")':'Indicator Value (Text)'})
tz_policy = tz_policy.drop(['Indicator Defined by Source? (yes/no)'],axis=1)

# %%
tz_policy['Characteristic Category'] = 'Total'
tz_policy['Characteristic Label'] = 'Total'
tz_policy['Year'] = tz_policy['Most Recent Year Available']
tz_policy['Indicator Value (Numeric)'] = np.nan

# %%
merged2 = merged.append(tz_policy, ignore_index=True)

# %%
ng = pd.read_excel("C:/Users/kusht/Downloads/policy/Nigeria Indicator sources and metadata (2).xlsx", sheetname='Indicator Metadata')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
ng_policy = ng[ng['Indicator Source (linked to IS sheet)'] != 'Nigeria HMIS']

# %%
ng_policy.columns.tolist()
ng_policy = ng_policy.rename(columns={'Type of data source':'Type of Data Source','Indicator Definition (per source, or PATH definition if source does not defined)':'Indicator Definition (per source, or PATH definition if source does not define)','Indicator Name (as used in indicator source)':'Indicator Name','Indicator Source (linked to IS sheet)':'Data Source','Asset (drop-down)':'Asset','Stage and ID (drop-down)':'Stage and ID','Milestone and ID (drop-down)':'Milestone and ID','Priority Milestone (Y/N)':'Priority Milestone (Yes/No)','Closest to Coverage? (Y/N)':'Closest to coverage','Indicator Value (Yes/No/NA). Asset included in policy/guidelines? Only applies to country-specific data (not "All Countries")':'Indicator Value (Text)'})
ng_policy = ng_policy.drop(['Indicator Defined by Source? (yes/no)'],axis=1)

# %%
ng_policy['Characteristic Category'] = 'Total'
ng_policy['Characteristic Label'] = 'Total'
ng_policy['Year'] = ng_policy['Most Recent Year Available']
ng_policy['Indicator Value (Numeric)'] = np.nan

# %%
merged2 = merged2.append(ng_policy, ignore_index=True)

# %%
ke = pd.read_excel("C:/Users/kusht/Downloads/policy/Kenya Indicator sources and metadata (1).xlsx", sheetname='Indicator Metadata')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
ke_policy = ke[ke['Indicator Source (linked to IS sheet)'] != 'Kenya HMIS']

# %%
ke_policy.columns.tolist()
ke_policy = ke_policy.rename(columns={'Type of data source':'Type of Data Source','Indicator Definition (per source, or PATH definition if source does not defined)':'Indicator Definition (per source, or PATH definition if source does not define)','Indicator Name\xa0':'Indicator Name','Indicator Source (linked to IS sheet)':'Data Source','Asset (drop-down)':'Asset','Stage and ID (drop-down)':'Stage and ID','Milestone and ID (drop-down)':'Milestone and ID','Priority Milestone (Y/N)':'Priority Milestone (Yes/No)','Closest to Coverage':'Closest to coverage','Indicator Value (Yes/No/NA). Asset included in policy/guidelines? Only applies to country-specific data (not "All Countries")':'Indicator Value (Text)'})
ke_policy = ke_policy.drop(['Indicator Defined by Source? (yes/no)'],axis=1)

# %%
ke_policy['Characteristic Category'] = 'Total'
ke_policy['Characteristic Label'] = 'Total'
ke_policy['Year'] = ke_policy['Most Recent Year Available']
ke_policy['Indicator Value (Numeric)'] = np.nan

# %%
merged2 = merged2.append(ke_policy, ignore_index=True)

# %%
bf = pd.read_excel("C:/Users/kusht/Downloads/policy/Burkina Faso Indicator sources and metadata (2).xlsx", sheetname='Indicator Metadata')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
bf_policy = bf[bf['Indicator Source (linked to IS sheet)'] != 'HMIS']

# %%
bf_policy.columns.tolist()
bf_policy = bf_policy.rename(columns={'Type of data source':'Type of Data Source','Indicator Definition (per source, or PATH definition if source does not defined)':'Indicator Definition (per source, or PATH definition if source does not define)','Indicator Name (as used in indicator source)':'Indicator Name','Indicator Source (linked to IS sheet)':'Data Source','Asset (drop-down)':'Asset','Stage and ID (drop-down)':'Stage and ID','Milestone and ID (drop-down)':'Milestone and ID','Priority Milestone? (Y/N)':'Priority Milestone (Yes/No)','Closest to Coverage? (Y/N)':'Closest to coverage','Indicator Value (Yes/No/NA). Asset included in policy/guidelines? Only applies to country-specific data (not "All Countries")':'Indicator Value (Text)'})
#bf_policy = bf_policy.drop(['Indicator Defined by Source? (yes/no)'],axis=1)

# %%
bf_policy['Characteristic Category'] = 'Total'
bf_policy['Characteristic Label'] = 'Total'
bf_policy['Year'] = bf_policy['Most Recent Year Available']
bf_policy['Indicator Value (Numeric)'] = np.nan

# %%
merged2 = merged2.append(bf_policy, ignore_index=True)

# %%
mw = pd.read_excel("C:/Users/kusht/Downloads/policy/Malawi Indicator sources and metadata (2).xlsx", sheetname='Indicator Metadata')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
mw_policy = mw[mw['Indicator Source (linked to IS sheet)'] != 'Malawi HMIS']

# %%
mw_policy.columns.tolist()
mw_policy = mw_policy.rename(columns={'Type of data source':'Type of Data Source','Indicator Definition (per source, or PATH definition if source does not defined)':'Indicator Definition (per source, or PATH definition if source does not define)','Indicator Name (as used in indicator source)':'Indicator Name','Indicator Source (linked to IS sheet)':'Data Source','Asset (drop-down)':'Asset','Stage and ID (drop-down)':'Stage and ID','Milestone and ID (drop-down)':'Milestone and ID','Priority Milestone? (Y/N)':'Priority Milestone (Yes/No)','Closest to coverage (Y/N)':'Closest to coverage','Indicator Value (Yes/No/NA). Asset included in policy/guidelines? Only applies to country-specific data (not "All Countries")':'Indicator Value (Text)'})
mw_policy = mw_policy.drop(['Indicator Defined by Source? (yes/no)'],axis=1)

# %%
mw_policy['Characteristic Category'] = 'Total'
mw_policy['Characteristic Label'] = 'Total'
mw_policy['Year'] = mw_policy['Most Recent Year Available']
mw_policy['Indicator Value (Numeric)'] = np.nan

# %%
merged2 = merged2.append(mw_policy, ignore_index=True)

# %%
et = pd.read_excel("C:/Users/kusht/Downloads/policy/Ethiopia Indicator sources and metadata (2).xlsx", sheetname='Indicator Metadata')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
et_policy = et[et['Indicator Source (linked to IS sheet)'] != 'Ethiopia HMIS']

# %%
et_policy.columns.tolist()
et_policy = et_policy.rename(columns={'Type of data source':'Type of Data Source','Indicator Definition (per source, or PATH definition if source does not defined)':'Indicator Definition (per source, or PATH definition if source does not define)','Indicator Name (as used in indicator source)':'Indicator Name','Indicator Source (linked to IS sheet)':'Data Source','Asset (drop-down)':'Asset','Stage and ID (drop-down)':'Stage and ID','Milestone and ID (drop-down)':'Milestone and ID','Priority Milestone? (Y/N)':'Priority Milestone (Yes/No)','Closest to coverage (Y/N)':'Closest to coverage','Indicator Value (Yes/No/NA). Asset included in policy/guidelines? Only applies to country-specific data (not "All Countries")':'Indicator Value (Text)','Priority Indicator (Y/N)':'Priority Indicator? (Yes/No)'})
et_policy = et_policy.drop(['Indicator Defined by Source? (yes/no)'],axis=1)

# %%
et_policy['Characteristic Category'] = 'Total'
et_policy['Characteristic Label'] = 'Total'
et_policy['Year'] = et_policy['Most Recent Year Available']
et_policy['Indicator Value (Numeric)'] = np.nan

# %%
merged2 = merged2.append(et_policy, ignore_index=True)

# %%
ia = pd.read_excel("C:/Users/kusht/Downloads/policy/India Indicator sources and metadata (1).xlsx", sheetname='Indicator Metadata')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
ia_policy = ia_policy[ia_policy['Indicator Source (linked to IS sheet)'] != 'BHMIS (Bihar Health Management Information System)']

# %%
ia_policy.columns.tolist()
ia_policy = ia_policy.rename(columns={'Type of data source':'Type of Data Source','Indicator Definition (per source, or PATH definition if source does not defined)':'Indicator Definition (per source, or PATH definition if source does not define)','Indicator Name (as used in indicator source)':'Indicator Name','Indicator Source (linked to IS sheet)':'Data Source','Asset (drop-down)':'Asset','Stage and ID (drop-down)':'Stage and ID','Milestone and ID (drop-down)':'Milestone and ID','Priority Milestone? (Y/N)':'Priority Milestone (Yes/No)','Closest to coverage (Y/N)':'Closest to coverage','Indicator Value (Yes/No/NA). Asset included in policy/guidelines? Only applies to country-specific data (not "All Countries")':'Indicator Value (Text)','Priority Indicator (Y/N)':'Priority Indicator? (Yes/No)'})
ia_policy = ia_policy.drop(['Indicator Defined by Source? (yes/no)'],axis=1)

# %%
ia_policy['Characteristic Category'] = 'Total'
ia_policy['Characteristic Label'] = 'Total'
ia_policy['Year'] = ia_policy['Most Recent Year Available']
ia_policy['Indicator Value (Numeric)'] = np.nan

# %%
merged2 = merged2.append(ia_policy, ignore_index=True)

# %%
#Check for Yes/No - 1/0
for idx, i in enumerate(merged2['Indicator Value (Text)']):
    if i == 'Yes':
        merged2['Indicator Value (Text)'].loc[idx] = 'Y'
        merged2['Indicator Value (Numeric)'].loc[idx] = np.nan

# %%
from IPython.display import FileLink, FileLinks

merged2.to_csv('C:/Users/kusht/Downloads/saved/Merged_Data_v11.csv', index=False)

# %%
missing = pd.read_csv("C:/Users/kusht/Downloads/saved/Merged_Data_v12.csv")

# %%
missing
# Out:
#                                 Accessibility                  Asset  \
# 0       Country accessible, manual extraction         Amoxicillin DT
# 1       Country accessible, manual extraction          Chlorhexidine
# 2       Country accessible, manual extraction        Iron-Folic Acid
# 3       Country accessible, manual extraction                  MgSo4
# 4       Country accessible, manual extraction            Misoprostol
# 5       Country accessible, manual extraction               Oxytocin
# 6       Country accessible, manual extraction                   PSBI
# 7       Country accessible, manual extraction                    KMC
# 8       Country accessible, manual extraction  Newborn Resuscitation
# 9      Publicly accessible, manual extraction         Amoxicillin DT
# 10     Publicly accessible, manual extraction          Chlorhexidine
# 11     Publicly accessible, manual extraction        Iron-Folic Acid
# 12     Publicly accessible, manual extraction                    KMC
# ...

# %%
nonmissing = missing.iloc[:12528]

# %%
from IPython.display import FileLink, FileLinks

nonmissing.to_csv('C:/Users/kusht/Downloads/saved/Merged_Data_v13.csv', index=False)
