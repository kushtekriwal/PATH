# %%
import pandas as pd
import numpy as np

# %%
gl = pd.read_csv("C:/Users/kusht/Downloads/Merged_Data_v5.csv")

# %%
gl = gl.drop(['Data Source', 'Year', 'Characteristic Category', 'Characteristic Label', 'Indicator Value (Numeric)', 'Indicator Value (Text)'], axis=1)
gl.columns.tolist()
# Out:
# ['Accessibility',
#  'Asset',
#  'Closest to coverage',
#  'Country',
#  'Data Quality Considerations (representative, standardized data collection methods)',
#  'Direct Indicator? (yes/no)',
#  'Frequency Notes (# of years, frequency)',
#  'Indicator Defined by Source? (yes/no)',
#  'Indicator Definition (per source, or PATH definition if source does not define)',
#  'Milestone and ID',
#  'Most Recent Year Available',
#  'Notes and Considerations',
#  'Panel Data Available (y/n)',
#  'Priority Indicator? (Yes/No)',
#  'Priority Milestone (Yes/No)',
#  'Stage and ID',
#  'Type of Data Source',
#  'Indicator Name']

# %%
gl
# Out:
#                                      Accessibility                  Asset  \
# 0     Publicly accessible, automatically extracted         Amoxicillin DT
# 1      Country accessible, automatically extracted         Amoxicillin DT
# 2     Publicly accessible, automatically extracted          Chlorhexidine
# 3     Publicly accessible, automatically extracted        Iron-Folic Acid
# 4      Country accessible, automatically extracted        Iron-Folic Acid
# 5     Publicly accessible, automatically extracted        Iron-Folic Acid
# 6     Publicly accessible, automatically extracted        Iron-Folic Acid
# 7      Country accessible, automatically extracted        Iron-Folic Acid
# 8     Publicly accessible, automatically extracted                    KMC
# 9     Publicly accessible, automatically extracted                  MgSo4
# 10     Country accessible, automatically extracted                  MgSo4
# 11    Publicly accessible, automatically extracted                  MgSo4
# ...

# %%
model = pd.read_csv("C:/Users/kusht/Downloads/saved/model.csv")

# %%
model = model[['Data Source', 'Country','Year', 'Characteristic Category', 'Characteristic Label', 'Indicator Name', 'Indicator Value (Numeric)', 'Indicator Value (Text)']]

# %%
mw = pd.read_excel("C:/Users/kusht/Downloads/policy/Malawi Indicator sources and metadata.xlsx")
mw
# Out:
#                                      Indicator Source  \
# 0                                         DHS surveys
# 1                                  DHS newborn module
# 2        DHS supplemental module maternal health care
# 3               DHS Service Provision Assesment (SPA)
# 4   WHO Global Database on the Implementation of N...
# 5   e-Library of Evidence for Nutrition Actions (e...
# 6   Global Reproductive, Maternal, Newborn, Child ...
# 7            Global Nutrition Policy Review 2016-2017
# 8   Service Availability and Readiness Assesment (...
# 9                      Every Newborn Action Plan ENAP
# 10     ICEH International Center for Equity in Health
# 11                                  Countdown to 2030
# 12                                              DHIS2
# 13          Multiple Indicator Cluster Survey (MICS)
# 14  Access, Bottlenecks, Costs and Equity Project ...
# 15                            WHO repository for NEML
# ...

# %%
maw = mw[mw['Indicator Source (linked to IS sheet)'] != 'Malawi HMIS' ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Indicator Source (linked to IS sheet)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-272-74e9bb74b421> in <module>()
# ...

# %%
keny
# Out:
#                                            Data Source Country       Year  \
# 0                                        IMNCI Booklet   Kenya       2018
# 1                                        IMNCI Booklet   Kenya       2018
# 2                                        IMNCI Booklet   Kenya       2018
# 3                                        IMNCI Booklet   Kenya       2018
# 4                                        IMNCI Booklet   Kenya       2018
# 5                                        IMNCI Booklet   Kenya       2018
# 6                                        IMNCI Booklet   Kenya       2018
# 7                                        IMNCI Booklet   Kenya       2018
# 8                                        IMNCI Booklet   Kenya       2018
# 9    A guideline for the use of chlorhexidine for n...   Kenya          ?
# 10   A guideline for the use of chlorhexidine for n...   Kenya        NaN
# 11   A National framework and plan of action for im...   Kenya  2013-2018
# ...

# %%
keny = pd.DataFrame(columns=['Data Source', 'Country', 'Year', 'Characteristic Category', 'Characteristic Label', 'Indicator Name', 'Indicator Value (Numeric)', 'Indicator Value (Text)'])
keny['Data Source'] = ken['Indicator Source (linked to IS sheet)']
keny['Country'] = 'Kenya'
keny['Year'] = ken['Most Recent Year Available']
keny['Characteristic Category'] = 'Total'
keny['Characteristic Label'] = 'Total'
keny['Indicator Name'] = ken['Indicator Name\xa0']
keny['Indicator Value (Text)'] = ken['Indicator Value (Yes/No/NA). Asset included in policy/guidelines? Only applies to country-specific data (not "All Countries")']

# %%
for idx, i in enumerate(keny['Indicator Value (Text)']):
    if i == 'Y':
        keny['Indicator Value (Numeric)'].loc[idx] = 1
    elif i == 'N':
        keny['Indicator Value (Numeric)'].loc[idx] = 0

# %%
ke = ke.rename(columns={'Asset (drop-down)':'Asset','Stage and ID (drop-down)':'Stage and ID', 'Milestone and ID (drop-down)':'Milestone and ID', 'Indicator Name\xa0':'Indicator Name','Type of data source':'Type of Data Source'})
ke = ke.drop(['Indicator Value (Yes/No/NA). Asset included in policy/guidelines? Only applies to country-specific data (not "All Countries")','Indicator Source (linked to IS sheet)'], axis=1)

# %%
gl = gl.append(ke, ignore_index=True)

# %%
model = model.append(keny, ignore_index=True)

# %%
joined_data = pd.merge(gl, model, left_on=['Indicator Name','Country'], right_on=['Indicator Name', 'Country'], how='right')

# %%
joined_data[joined_data['Country'] == 'Kenya']['Data Source'].unique()
# Out:
# array([' IMNCI Booklet',
#        'A guideline for the use of chlorhexidine for newborn umblical cord care in Kenya',
#        'KMC guidelines',
#        'National Guidelines for quality obstetrics & perinatal care',
#        'National IFA guidelines for pregnant mothers',
#        'A National framework and plan of action for implementation of intergrated communitycase management',
#        'Baby Friendly community Initiative',
#        'Clinical guidelines for management and referral of common conditions at levels 2-3: primary care',
#        'IMNCI participants manual', nan,
#        'Kangaroo Mother care clinical implementation guidelines',
#        'Kenya EMSL', 'Kenya Essential Medicine List',
#        'Kenya Health sector strategic plan',
#        'Kenya Reproductive , maternal, newborn, child and Adolescent health Framework',
#        'Maternal and Newborn Health Implementation plan ',
#        'National Maternal, Infant & Young child nutrition',
# ...

# %%
joined_data[(joined_data['Country'] == 'Kenya') & (joined_data['Data Source'] == 'Integrated Management of Childhood Illness (IMCI) global survey report')]
# Out:
#       Accessibility Asset Closest to Coverage Closest to coverage Country  \
# 24142           NaN   NaN                 NaN                 NaN   Kenya
# 24143           NaN   NaN                 NaN                 NaN   Kenya
#
#       Data Quality Considerations (representative, standardized data collection methods)  \
# 24142                                                NaN
# 24143                                                NaN
#
#       Direct Indicator? (yes/no) Frequency Notes (# of years, frequency)  \
# 24142                        NaN                                     NaN
# 24143                        NaN                                     NaN
#
#       Indicator Defined by Source? (yes/no)  \
# 24142                                   NaN
# 24143                                   NaN
#
#       Indicator Definition (per source, or PATH definition if source does not define)  \
# 24142                                                NaN
# ...

# %%
model[model['Country'] == 'Tanzania']
# Out:
#                                  Data Source   Country  Year  \
# 54     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 56     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 57     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 59     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 60     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 62     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 63     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 65     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 66     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 68     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 70     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 72     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 73     DHS Service Provision Assesment (SPA)  Tanzania  2015
# 74     DHS Service Provision Assesment (SPA)  Tanzania  2015
# ...

# %%
model = model.append(etpo, ignore_index=True)

# %%
model = model.drop_duplicates(keep='first')

# %%
from IPython.display import FileLink, FileLinks

gl.to_csv('C:/Users/kusht/Downloads/saved/gl2.csv', index=False)

# %%
joined_data = joined_data.drop_duplicates(keep='first')

# %%
model[(model['Country'] == 'Kenya') & (model['Data Source'] == 'HMIS')]
# Out:
#       Data Source Country    Year Characteristic Category  \
# 13300        HMIS   Kenya  2014.0                   Total
# 13301        HMIS   Kenya  2014.0                  Region
# 13302        HMIS   Kenya  2014.0                  Region
# 13303        HMIS   Kenya  2014.0                  Region
# 13304        HMIS   Kenya  2014.0                  Region
# 13305        HMIS   Kenya  2014.0                  Region
# 13306        HMIS   Kenya  2014.0                  Region
# 13307        HMIS   Kenya  2014.0                  Region
# 13308        HMIS   Kenya  2014.0                  Region
# 13309        HMIS   Kenya  2014.0                  Region
# 13310        HMIS   Kenya  2014.0                  Region
# 13311        HMIS   Kenya  2014.0                  Region
# 13312        HMIS   Kenya  2014.0                  Region
# 13313        HMIS   Kenya  2014.0                  Region
# 13314        HMIS   Kenya  2014.0                  Region
# ...

# %%
ke[(ke['Country'] == 'Kenya') & (ke['Indicator Source (linked to IS sheet)'] == 'Kenya HMIS')]
# Out:
#    Asset (drop-down) Stage and ID (drop-down)  \
# 54   Iron-Folic Acid             6 - Coverage
# 55   Iron-Folic Acid             6 - Coverage
# 56   Iron-Folic Acid             6 - Coverage
# 57   Iron-Folic Acid             6 - Coverage
# 58             MgSo4             6 - Coverage
# 59   Iron-Folic Acid             6 - Coverage
# 60             MgSo4             6 - Coverage
# 61   Iron-Folic Acid             6 - Coverage
# 62             MgSo4             6 - Coverage
# 63   Iron-Folic Acid             6 - Coverage
# 64             MgSo4             6 - Coverage
# 65   Iron-Folic Acid             6 - Coverage
# 66             MgSo4             6 - Coverage
# 67   Iron-Folic Acid             6 - Coverage
# 68             MgSo4             6 - Coverage
#
#             Milestone and ID (drop-down) Priority Indicator? (Yes/No)  \
# 54  6.8.2 - Population Coverage Achieved                            Y
# 55  6.8.2 - Population Coverage Achieved                            Y
# ...

# %%
joined_data[(joined_data['Country'] == 'Tanzania') & (joined_data['Data Source'] == 'HMIS')]
# Out:
#                                       Accessibility            Asset  \
# 825531  Country accessible, automatically extracted              KMC
# 825537  Country accessible, automatically extracted              KMC
# 825543  Country accessible, automatically extracted              KMC
# 825549  Country accessible, automatically extracted              KMC
# 825555  Country accessible, automatically extracted              KMC
# 825561  Country accessible, automatically extracted              KMC
# 825567  Country accessible, automatically extracted              KMC
# 825573  Country accessible, automatically extracted              KMC
# 825579  Country accessible, automatically extracted              KMC
# 825585  Country accessible, automatically extracted              KMC
# 825591  Country accessible, automatically extracted              KMC
# 825597  Country accessible, automatically extracted              KMC
# 825603  Country accessible, automatically extracted  Iron-Folic Acid
# ...

# %%
joined_data[joined_data['Indicator Name'] == np.nan]
# Out:
# Empty DataFrame
# Columns: [Accessibility, Asset, Closest to Coverage, Closest to coverage, Country, Data Quality Considerations (representative, standardized data collection methods), Direct Indicator? (yes/no), Frequency Notes (# of years, frequency), Indicator Defined by Source? (yes/no), Indicator Definition (per source, or PATH definition if source does not define), Indicator Name, Milestone and ID, Most Recent Year Available, Notes and Considerations, Panel Data Available (y/n), Priority Indicator? (Yes/No), Priority Milestone (Yes/No), Stage and ID, Type of Data Source, Data Source, Year, Characteristic Category, Characteristic Label, Indicator Value (Numeric), Indicator Value (Text)]
# Index: []
#
# [0 rows x 25 columns]

# %%
model[(model['Country'] == 'Kenya') & (model['Data Source'] == 'HMIS')]['Indicator Name'].unique()
# Out:
# array(['no of clients given combined  iron &folate',
#        'anc client given iron', 'No. of anc client given folate',
#        'No. anc syphilis', '% anc 1 coverage', 'No. of anc attendance',
#        'No. of new anc clients', 'No. of anc 4 visits',
#        '4th antenatal care (anc) coverage ()',
#        'No. of. re-visit anc clients', 'aph', 'no of. Eclampsia cases',
#        'obstructed labour', 'pph', 'ruptured uterus', 'sepsis',
#        'assisted vd', 'neonatal deaths', 'normal deliveries',
#        'estimated deliveries', 'estimated eoc',
#        'estimated number of pregnant women', '% est pregnant women',
#        '% skilled birth attendants', 'estimate live births',
#        'population _lt1y', 'children under five treated for pneumonia',
#        'neonatal death rate', 'of perinatal deaths audited', 'fmmr',
#        'fresh still birth rate', 'perinatal deaths',
#        'of maternal death audited', 'total hf deliveries'], dtype=object)

# %%
joined_data[(joined_data['Country'] == 'Kenya') & (joined_data['Indicator Name'] == 'No. anc syphilis')]
# Out:
#        Accessibility Asset Closest to Coverage Closest to coverage Country  \
# 839222           NaN   NaN                 NaN                 NaN   Kenya
# 839223           NaN   NaN                 NaN                 NaN   Kenya
# 839224           NaN   NaN                 NaN                 NaN   Kenya
# 839225           NaN   NaN                 NaN                 NaN   Kenya
# 839226           NaN   NaN                 NaN                 NaN   Kenya
# 839227           NaN   NaN                 NaN                 NaN   Kenya
# 839228           NaN   NaN                 NaN                 NaN   Kenya
# 839229           NaN   NaN                 NaN                 NaN   Kenya
# 839230           NaN   NaN                 NaN                 NaN   Kenya
# 839231           NaN   NaN                 NaN                 NaN   Kenya
# 839232           NaN   NaN                 NaN                 NaN   Kenya
# ...

# %%
joined_data.iloc[1200]
# Out:
# Accessibility                                                                              Publicly accessible, automatically extracted
# Asset                                                                                                                    Amoxicillin DT
# Closest to Coverage                                                                                                                 NaN
# Closest to coverage                                                                                                                   N
# Country                                                                                                                        Ethiopia
# Data Quality Considerations (representative, standardized data collection methods)                                                  NaN
# Direct Indicator? (yes/no)                                                                                                            N
# ...
