# %%
import pandas as pd
import numpy as np

# %%
dhsfocus = pd.read_csv("C:/Users/kusht/Downloads/DHS_Processed_v3.csv")

# %%
dhsfocus
# Out:
#            Country  Year Characteristic Category     Characteristic Label  \
# 0     Burkina Faso  1993                   Total                    Total
# 1     Burkina Faso  1993                     Sex                     Male
# 2     Burkina Faso  1993                     Sex                   Female
# 3     Burkina Faso  1993             Child's age           Under 6 months
# 4     Burkina Faso  1993             Child's age              6-11 months
# 5     Burkina Faso  1993             Child's age             12-23 months
# 6     Burkina Faso  1993             Child's age             24-35 months
# 7     Burkina Faso  1993             Child's age             36-47 months
# 8     Burkina Faso  1993             Child's age             48-59 months
# 9     Burkina Faso  1993               Residence                    Urban
# 10    Burkina Faso  1993               Residence                    Rural
# 11    Burkina Faso  1993               Education             No education
# ...

# %%
dhsall = pd.read_csv("C:/Users/kusht/Downloads/DHS_Processed_v4.csv")

# %%
dhsall['Data Source'] = 'DHS'
dhsall
# Out:
#                                 Country  Year Characteristic Category  \
# 0                           Afghanistan  2015                   Total
# 1                                Angola  2015                   Total
# 2                            Azerbaijan  2006                   Total
# 3                               Burundi  2010                   Total
# 4                              Cambodia  2005                   Total
# 5                               Comoros  2012                   Total
# 6                                 Congo  2005                   Total
# 7                                 Congo  2011                   Total
# 8    Congo (Democratic Republic of the)  2007                   Total
# 9    Congo (Democratic Republic of the)  2013                   Total
# 10                                Gabon  2012                   Total
# 11                               Gambia  2013                   Total
# ...

# %%
focuscountries = np.array(dhsfocus['Country'].unique())
print(focuscountries)
# Out:
# ['Burkina Faso' 'Ethiopia' 'India' 'Malawi' 'Nigeria' 'Kenya' 'Tanzania']

# %%
dhsall = dhsall[dhsall['Country'] != 'Tanzania']

# %%
dhsall = dhsall.rename(columns={"Indicator Value":"Indicator Value (Numeric)"})
dhsall['Indicator Value (Text)'] = np.nan

# %%
enap = pd.read_csv("C:/Users/kusht/Downloads/ENAP_Processed_v3.csv")

# %%
enap
# Out:
#                                       Country  \
# 0                                 Afghanistan
# 1                                      Angola
# 2                                  Azerbaijan
# 3                                  Bangladesh
# 4                                       Benin
# 5                                      Bhutan
# 6                                Burkina Faso
# 7                                     Burundi
# 8                                    Cameroon
# 9                    Central African Republic
# 10                                       Chad
# 11                                    Comoros
# 12                                      Congo
# 13         Congo (Democratic Republic of the)
# 14                              Côte d'Ivoire
# 15                                   Djibouti
# 16                          Equatorial Guinea
# 17                                    Eritrea
# 18                                   Ethiopia
# ...

# %%
enap['Year'] = 2018
enap['Characteristic Category'] = 'Total'
enap['Characteristic Label'] = 'Total'
enap['Data Source'] = 'ENAP'

# %%
gho = pd.read_csv("C:/Users/kusht/Downloads/GHO Country Data.csv",encoding = 'unicode_escape')

# %%
gho
# Out:
#      Data Source      Country  Year Characteristic Category  \
# 0            GHO  Afghanistan  2000                   Total
# 1            GHO  Afghanistan  2001                   Total
# 2            GHO  Afghanistan  2002                   Total
# 3            GHO  Afghanistan  2002                   Total
# 4            GHO  Afghanistan  2002                   Total
# 5            GHO  Afghanistan  2003                   Total
# 6            GHO  Afghanistan  2003                   Total
# 7            GHO  Afghanistan  2003                   Total
# 8            GHO  Afghanistan  2003                   Total
# 9            GHO  Afghanistan  2004                   Total
# 10           GHO  Afghanistan  2004                   Total
# 11           GHO  Afghanistan  2004                   Total
# 12           GHO  Afghanistan  2004                   Total
# 13           GHO  Afghanistan  2005                   Total
# 14           GHO  Afghanistan  2005                   Total
# ...

# %%
gho = gho.rename(columns={"Indicator Value":"Indicator Value (Numeric)", "IndicatorName":"Indicator Name"})
gho['Characteristic Label'] = 'Total'
gho['Indicator Value (Text)'] = np.nan

# %%
lookup = pd.read_csv("C:/Users/kusht/Downloads/Country Lookup_v3.csv")

# %%
gho['Country'].unique()
# Out:
# array(['Afghanistan', 'Algeria', 'Angola', 'Azerbaijan', 'Bangladesh',
#        'Benin', 'Bhutan', 'Bolivia (Plurinational State of)', 'Botswana',
#        'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Central African Republic', 'Chad', 'Comoros', 'Congo',
#        'Congo (Democratic Republic of the)', "Côte d'Ivoire", 'Djibouti',
#        'Dominican Republic', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Gabon', 'Gambia', 'Ghana', 'Guatemala', 'Guinea', 'Guinea-Bissau',
#        'Guyana', 'Haiti', 'Honduras', 'India', 'Indonesia', 'Iraq',
#        'Jamaica', 'Kenya', "Korea (Democratic People's Republic of)",
#        'Kyrgyzstan', "Lao People's Democratic Republic", 'Lesotho',
#        'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Morocco',
#        'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Nicaragua', 'Niger',
#        'Nigeria', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay',
# ...

# %%
for idx,i in enumerate(gho['Country']):
    if i == 'Côte d\x92Ivoire':
        gho['Country'].loc[idx] = 'Côte d\'Ivoire'
# Out:
# C:\Users\kusht\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
model = pd.DataFrame(columns=['Data Source', 'Country', 'Year', 'Characteristic Category', 'Characteristic Label','Indicator Name', 'Indicator Value (Numeric)', 'Indicator Value (Text)'])
model['Country'] = dhsfocus['Country']
model['Year'] = dhsfocus['Year']
model['Characteristic Category'] = dhsfocus['Characteristic Category']
model['Characteristic Label'] = dhsfocus['Characteristic Label']
model['Indicator Name'] = dhsfocus['Indicator Name']
model['Indicator Value (Numeric)'] = dhsfocus['Indicator Value']
model['Data Source'] = 'DHS'

# %%
model
# Out:
#      Data Source       Country  Year Characteristic Category  \
# 0            DHS  Burkina Faso  1993                   Total
# 1            DHS  Burkina Faso  1993                     Sex
# 2            DHS  Burkina Faso  1993                     Sex
# 3            DHS  Burkina Faso  1993             Child's age
# 4            DHS  Burkina Faso  1993             Child's age
# 5            DHS  Burkina Faso  1993             Child's age
# 6            DHS  Burkina Faso  1993             Child's age
# 7            DHS  Burkina Faso  1993             Child's age
# 8            DHS  Burkina Faso  1993             Child's age
# 9            DHS  Burkina Faso  1993               Residence
# 10           DHS  Burkina Faso  1993               Residence
# 11           DHS  Burkina Faso  1993               Education
# 12           DHS  Burkina Faso  1993               Education
# 13           DHS  Burkina Faso  1993               Education
# ...

# %%
model = model.append(dhsall, ignore_index=True)

# %%
model = model.append(enap, ignore_index=True)

# %%
model = model.append(gho, ignore_index=True)

# %%
model
# Out:
#       Characteristic Category     Characteristic Label       Country  \
# 0                       Total                    Total  Burkina Faso
# 1                         Sex                     Male  Burkina Faso
# 2                         Sex                   Female  Burkina Faso
# 3                 Child's age           Under 6 months  Burkina Faso
# 4                 Child's age              6-11 months  Burkina Faso
# 5                 Child's age             12-23 months  Burkina Faso
# 6                 Child's age             24-35 months  Burkina Faso
# 7                 Child's age             36-47 months  Burkina Faso
# 8                 Child's age             48-59 months  Burkina Faso
# 9                   Residence                    Urban  Burkina Faso
# 10                  Residence                    Rural  Burkina Faso
# 11                  Education             No education  Burkina Faso
# 12                  Education                  Primary  Burkina Faso
# ...

# %%
cols = model.columns.tolist()
cols
# Out:
# ['Characteristic Category',
#  'Characteristic Label',
#  'Country',
#  'Data Source',
#  'Indicator Name',
#  'Indicator Value (Numeric)',
#  'Indicator Value (Text)',
#  'Year']

# %%
cols = [cols[3]] + [cols[2]] + [cols[7]] + [cols[0]] + [cols[1]] + [cols[4]] + [cols[5]] + [cols[6]]
cols
# Out:
# ['Data Source',
#  'Country',
#  'Year',
#  'Characteristic Category',
#  'Characteristic Label',
#  'Indicator Name',
#  'Indicator Value (Numeric)',
#  'Indicator Value (Text)']

# %%
model = model[cols]
model
# Out:
#       Data Source       Country  Year Characteristic Category  \
# 0             DHS  Burkina Faso  1993                   Total
# 1             DHS  Burkina Faso  1993                     Sex
# 2             DHS  Burkina Faso  1993                     Sex
# 3             DHS  Burkina Faso  1993             Child's age
# 4             DHS  Burkina Faso  1993             Child's age
# 5             DHS  Burkina Faso  1993             Child's age
# 6             DHS  Burkina Faso  1993             Child's age
# 7             DHS  Burkina Faso  1993             Child's age
# 8             DHS  Burkina Faso  1993             Child's age
# 9             DHS  Burkina Faso  1993               Residence
# 10            DHS  Burkina Faso  1993               Residence
# 11            DHS  Burkina Faso  1993               Education
# 12            DHS  Burkina Faso  1993               Education
# 13            DHS  Burkina Faso  1993               Education
# ...

# %%
from IPython.display import FileLink, FileLinks

model.to_csv('~/Downloads/Final_11-19_v2.csv', index=False)

# %%
final2 = pd.read_csv("C:/Users/kusht/Downloads/Final_11-19_v2.csv")

# %%
model[model['Data Source'] == "ENAP"]
# Out:
#      Data Source                                  Country  Year  \
# 6470        ENAP                              Afghanistan  2018
# 6471        ENAP                                   Angola  2018
# 6472        ENAP                               Azerbaijan  2018
# 6473        ENAP                               Bangladesh  2018
# 6474        ENAP                                    Benin  2018
# 6475        ENAP                                   Bhutan  2018
# 6476        ENAP                             Burkina Faso  2018
# 6477        ENAP                                  Burundi  2018
# 6478        ENAP                                 Cameroon  2018
# 6479        ENAP                 Central African Republic  2018
# 6480        ENAP                                     Chad  2018
# 6481        ENAP                                  Comoros  2018
# 6482        ENAP                                    Congo  2018
# 6483        ENAP       Congo (Democratic Republic of the)  2018
# ...
