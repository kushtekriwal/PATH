# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/Users/kusht/Downloads/saved/modelf2.csv")

# %%
data[(data['Data Source'] == 'DHS') & (data['Country'] == 'India') & (data['Characteristic Category'] == 'Region')]['Characteristic Label'].unique()
# Out:
# array(['New Delhi', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Punjab', 'Rajasthan', 'Madhya Pradesh, inc Chhattisgarh',
#        '..Madhya Pradesh', '..Chhattisgarh',
#        'Uttar Pradesh, inc Uttarakhand', '..Uttar Pradesh',
#        '..Uttarakhand', 'Bihar, inc Jharkhand', '..Bihar', '..Jharkhand',
#        'Odisha', 'West Bengal', 'Arunachal Pradesh', 'Assam', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Sikkim', 'Tripura', 'Goa',
#        'Gujarat', 'Maharashtra', 'Andhra Pradesh including Telangana',
#        'Karnataka', 'Kerala', 'Tamil Nadu', '..Andhra Pradesh',
#        '..Telangana', 'Andaman and Nicobar Islands', 'Chandigarh',
#        'Dadra and Nagar Haveli', 'Daman and Diu', 'Lakshadweep',
#        'Puducherry'], dtype=object)

# %%
up = data[(data['Data Source'] == 'DHS') & (data['Country'] == 'India') & (data['Characteristic Label'] == '..Uttar Pradesh')]

# %%
up['Country'] = 'India: Uttar Pradesh'
up['Characteristic Category'] = 'Total'
up['Characteristic Label'] = 'Total'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
up
# Out:
#      Data Source               Country  Year Characteristic Category  \
# 1204         DHS  India: Uttar Pradesh  2006                   Total
# 1266         DHS  India: Uttar Pradesh  2006                   Total
# 1326         DHS  India: Uttar Pradesh  2006                   Total
# 1386         DHS  India: Uttar Pradesh  2006                   Total
# 1446         DHS  India: Uttar Pradesh  2006                   Total
# 1506         DHS  India: Uttar Pradesh  2006                   Total
# 1566         DHS  India: Uttar Pradesh  2006                   Total
# 1626         DHS  India: Uttar Pradesh  2006                   Total
# 1679         DHS  India: Uttar Pradesh  2015                   Total
# 1750         DHS  India: Uttar Pradesh  2015                   Total
# 1818         DHS  India: Uttar Pradesh  2015                   Total
# 1886         DHS  India: Uttar Pradesh  2015                   Total
# 1954         DHS  India: Uttar Pradesh  2015                   Total
# ...

# %%
bi = data[(data['Data Source'] == 'DHS') & (data['Country'] == 'India') & (data['Characteristic Label'] == '..Bihar')]

# %%
bi['Country'] = 'India: Bihar'
bi['Characteristic Category'] = 'Total'
bi['Characteristic Label'] = 'Total'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
bi
# Out:
#      Data Source       Country  Year Characteristic Category  \
# 1207         DHS  India: Bihar  2006                   Total
# 1269         DHS  India: Bihar  2006                   Total
# 1329         DHS  India: Bihar  2006                   Total
# 1389         DHS  India: Bihar  2006                   Total
# 1449         DHS  India: Bihar  2006                   Total
# 1509         DHS  India: Bihar  2006                   Total
# 1569         DHS  India: Bihar  2006                   Total
# 1629         DHS  India: Bihar  2006                   Total
# 1682         DHS  India: Bihar  2015                   Total
# 1753         DHS  India: Bihar  2015                   Total
# 1821         DHS  India: Bihar  2015                   Total
# 1889         DHS  India: Bihar  2015                   Total
# 1957         DHS  India: Bihar  2015                   Total
# 2025         DHS  India: Bihar  2015                   Total
# ...

# %%
data[(data['Country'] != 'India') & (data['Data Source'] == 'DHS')]
# Out:
#       Data Source       Country  Year Characteristic Category  \
# 0             DHS  Burkina Faso  1993                   Total
# 1             DHS  Burkina Faso  1993                     Sex
# 2             DHS  Burkina Faso  1993                     Sex
# 3             DHS  Burkina Faso  1993             Child's age
# 4             DHS  Burkina Faso  1993             Child's age
# 5             DHS  Burkina Faso  1993             Child's age
# 6             DHS  Burkina Faso  1993             Child's age
# 7             DHS  Burkina Faso  1993             Child's age
# 8             DHS  Burkina Faso  1993             Child's age
# 9             DHS  Burkina Faso  1993               Residence
# 10            DHS  Burkina Faso  1993               Residence
# 11            DHS  Burkina Faso  1993               Education
# 12            DHS  Burkina Faso  1993               Education
# 13            DHS  Burkina Faso  1993               Education
# ...

# %%
ia_enap = data[(data['Country'] == 'India') & (data['Data Source'] == 'ENAP')]

# %%
ia_enap2 = ia_enap.copy()
ia_enap['Country'] = 'India: Uttar Pradesh'
ia_enap2['Country'] = 'India: Bihar'
ia_enap_t = ia_enap.append(ia_enap2, ignore_index=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ia = bi.append(up, ignore_index=True)

# %%
ia = ia.append(ia_enap_t, ignore_index=True)

# %%
data = data[data['Country'] != 'India']

# %%
data = data.append(ia, ignore_index=True)

# %%
from IPython.display import FileLink, FileLinks

data.to_csv('C:/Users/kusht/Downloads/saved/modelf7.csv', index=False)

# %%
merged = pd.read_csv("C:/Users/kusht/Downloads/saved/Merged_Data_v13.csv")

# %%
merged['Data Source'].unique()
# Out:
# array(['National Agency for Food and Drug Administration (NAFDAQ)',
#        'Pharmaceutical Specialties and Generic Drugs Allowed in Burkina Faso',
#        'THE NATIONAL ROAD MAP STRATEGIC PLAN TO IMPROVE REPRODUCTIVE, MATERNAL, NEWBORN, CHILD & ADOLESCENT HEALTH IN TANZANIA (2016 - 2020)',
#        'Second National Strategic Health Development Plan', nan,
#        'National policy Infant, child, adolescent and young adult health',
#        'National policy health of women and infants less than 7 days old',
#        'National policy on obstetric and neonatal care',
#        'Malawi Community Health Strategy, 2017-2022', 'Malawi ENAP',
#        'Malawi National Sexual and Reproductive Health Strategy, 2018-2022',
#        'Road Map for Accelerating the reduction of Maternal and Neonatal Morbidity and Mortality in Malawi',
#        'National Strategy for Newborn and Child Survival in Ethiopia  \r\r\r\n2015/16-2019/20 ',
# ...

# %%
bf_sara = pd.read_excel("C:/Users/kusht/Downloads/125/BurkinaFaso_SARA_data_2018.xlsx")

# %%
bf_sara.columns.tolist()
# Out:
# ['Source',
#  'Country',
#  'Asset',
#  'Year',
#  'Milestone',
#  'Indicator Name (match)',
#  'Indicator Definition',
#  'Indicator Value',
#  'notes']

# %%
data = data[data['Data Source'] != 'Service Availability and Readiness Assesment (SARA)']

# %%
data
# Out:
#       Data Source               Country  Year Characteristic Category  \
# 0             DHS          Burkina Faso  1993                   Total
# 1             DHS          Burkina Faso  1993                     Sex
# 2             DHS          Burkina Faso  1993                     Sex
# 3             DHS          Burkina Faso  1993             Child's age
# 4             DHS          Burkina Faso  1993             Child's age
# 5             DHS          Burkina Faso  1993             Child's age
# 6             DHS          Burkina Faso  1993             Child's age
# 7             DHS          Burkina Faso  1993             Child's age
# 8             DHS          Burkina Faso  1993             Child's age
# 9             DHS          Burkina Faso  1993               Residence
# 10            DHS          Burkina Faso  1993               Residence
# 11            DHS          Burkina Faso  1993               Education
# ...

# %%
bf_sara2 = pd.DataFrame(columns=['Data Source',
 'Country',
 'Year',
 'Characteristic Category',
 'Characteristic Label',
 'Indicator Name',
 'Indicator Value (Numeric)',
 'Indicator Value (Text)'])
bf_sara2['Data Source'] = bf_sara['Source']
bf_sara2['Country'] = bf_sara['Country']
bf_sara2['Year'] = bf_sara['Year']
bf_sara2['Characteristic Category'] = 'Total'
bf_sara2['Characteristic Label'] = 'Total'
bf_sara2['Indicator Name'] = bf_sara['Indicator Name (match)']
bf_sara2['Indicator Value (Numeric)'] = bf_sara['Indicator Value']
bf_sara2['Indicator Value (Text)'] = np.nan

# %%
for idx, i in enumerate(bf_sara2['Indicator Value (Numeric)']):
    if i == 'Not in report':
        bf_sara2['Indicator Value (Numeric)'].loc[idx] = np.nan
        bf_sara2['Indicator Value (Text)'].loc[idx] = 'Not in report'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
bf_sara2
# Out:
#                                           Data Source       Country  Year  \
# 0   Service Availability and Readiness Assesment (...  Burkina Faso  2018
# 1   Service Availability and Readiness Assesment (...  Burkina Faso  2018
# 2   Service Availability and Readiness Assesment (...  Burkina Faso  2018
# 3   Service Availability and Readiness Assesment (...  Burkina Faso  2018
# 4   Service Availability and Readiness Assesment (...  Burkina Faso  2018
# 5   Service Availability and Readiness Assesment (...  Burkina Faso  2018
# 6   Service Availability and Readiness Assesment (...  Burkina Faso  2018
# 7   Service Availability and Readiness Assesment (...  Burkina Faso  2018
# 8   Service Availability and Readiness Assesment (...  Burkina Faso  2018
# 9   Service Availability and Readiness Assesment (...  Burkina Faso  2018
# 10  Service Availability and Readiness Assesment (...  Burkina Faso  2018
# 11  Service Availability and Readiness Assesment (...  Burkina Faso  2018
# ...

# %%
et_sara = pd.read_excel("C:/Users/kusht/Downloads/125/Ethiopia_SARA_data_2018 (1).xlsx")

# %%
et_sara
# Out:
#                                                Source    Country  \
# 0   Service Availability and Readiness Assesment (...  Ethiopia
# 1   Service Availability and Readiness Assesment (...  Ethiopia
# 2   Service Availability and Readiness Assesment (...  Ethiopia
# 3   Service Availability and Readiness Assesment (...  Ethiopia
# 4   Service Availability and Readiness Assesment (...  Ethiopia
# 5   Service Availability and Readiness Assesment (...  Ethiopia
# 6   Service Availability and Readiness Assesment (...  Ethiopia
# 7   Service Availability and Readiness Assesment (...  Ethiopia
# 8   Service Availability and Readiness Assesment (...  Ethiopia
# 9   Service Availability and Readiness Assesment (...  Ethiopia
# 10  Service Availability and Readiness Assesment (...  Ethiopia
# 11  Service Availability and Readiness Assesment (...  Ethiopia
# 12  Service Availability and Readiness Assesment (...  Ethiopia
# 13  Service Availability and Readiness Assesment (...  Ethiopia
# ...

# %%
et_sara2 = pd.DataFrame(columns=['Data Source',
 'Country',
 'Year',
 'Characteristic Category',
 'Characteristic Label',
 'Indicator Name',
 'Indicator Value (Numeric)',
 'Indicator Value (Text)'])
et_sara2['Data Source'] = et_sara['Source']
et_sara2['Country'] = et_sara['Country']
et_sara2['Year'] = et_sara['Year']
et_sara2['Characteristic Category'] = 'Total'
et_sara2['Characteristic Label'] = 'Total'
et_sara2['Indicator Name'] = et_sara['Indicator Name (match)']
et_sara2['Indicator Value (Numeric)'] = et_sara['Indicator Value']
et_sara2['Indicator Value (Text)'] = np.nan

# %%
for idx, i in enumerate(et_sara2['Indicator Value (Numeric)']):
    if i == 'Not in report':
        et_sara2['Indicator Value (Numeric)'].loc[idx] = np.nan
        et_sara2['Indicator Value (Text)'].loc[idx] = 'Not in report'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
et_sara2
# Out:
#                                           Data Source    Country  Year  \
# 0   Service Availability and Readiness Assesment (...  Ethiopia   2018
# 1   Service Availability and Readiness Assesment (...  Ethiopia   2018
# 2   Service Availability and Readiness Assesment (...  Ethiopia   2018
# 3   Service Availability and Readiness Assesment (...  Ethiopia   2018
# 4   Service Availability and Readiness Assesment (...  Ethiopia   2018
# 5   Service Availability and Readiness Assesment (...  Ethiopia   2018
# 6   Service Availability and Readiness Assesment (...  Ethiopia   2018
# 7   Service Availability and Readiness Assesment (...  Ethiopia   2018
# 8   Service Availability and Readiness Assesment (...  Ethiopia   2018
# 9   Service Availability and Readiness Assesment (...  Ethiopia   2018
# 10  Service Availability and Readiness Assesment (...  Ethiopia   2018
# 11  Service Availability and Readiness Assesment (...  Ethiopia   2018
# ...

# %%
sara = bf_sara2.append(et_sara2, ignore_index=True)

# %%
ng_sara = pd.read_excel("C:/Users/kusht/Downloads/125/Nigeria_SARA_data_2018.xlsx")

# %%
ng_sara2 = pd.DataFrame(columns=['Data Source',
 'Country',
 'Year',
 'Characteristic Category',
 'Characteristic Label',
 'Indicator Name',
 'Indicator Value (Numeric)',
 'Indicator Value (Text)'])
ng_sara2['Data Source'] = ng_sara['Source']
ng_sara2['Country'] = ng_sara['Country']
ng_sara2['Year'] = ng_sara['Year']
ng_sara2['Characteristic Category'] = 'Total'
ng_sara2['Characteristic Label'] = 'Total'
ng_sara2['Indicator Name'] = ng_sara['Indicator Name (match)']
ng_sara2['Indicator Value (Numeric)'] = ng_sara['Indicator Value']
ng_sara2['Indicator Value (Text)'] = np.nan

# %%
for idx, i in enumerate(ng_sara2['Indicator Value (Numeric)']):
    if i == 'Not in report':
        ng_sara2['Indicator Value (Numeric)'].loc[idx] = np.nan
        ng_sara2['Indicator Value (Text)'].loc[idx] = 'Not in report'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
ng_sara2
# Out:
#                                           Data Source  Country  Year  \
# 0   Service Availability and Readiness Assesment (...  Nigeria  2016
# 1   Service Availability and Readiness Assesment (...  Nigeria  2016
# 2   Service Availability and Readiness Assesment (...  Nigeria  2016
# 3   Service Availability and Readiness Assesment (...  Nigeria  2016
# 4   Service Availability and Readiness Assesment (...  Nigeria  2016
# 5   Service Availability and Readiness Assesment (...  Nigeria  2016
# 6   Service Availability and Readiness Assesment (...  Nigeria  2016
# 7   Service Availability and Readiness Assesment (...  Nigeria  2016
# 8   Service Availability and Readiness Assesment (...  Nigeria  2016
# 9   Service Availability and Readiness Assesment (...  Nigeria  2016
# 10  Service Availability and Readiness Assesment (...  Nigeria  2016
# 11  Service Availability and Readiness Assesment (...  Nigeria  2016
# 12  Service Availability and Readiness Assesment (...  Nigeria  2016
# ...

# %%
sara = sara.append(ng_sara2, ignore_index=True)

# %%
data = data.append(sara, ignore_index=True)

# %%
spa = data[data['Data Source'] == 'DHS Service Provision Assesment (SPA)']

# %%
spa = pd.read_excel("C:/Users/kusht/Downloads/125/SPA_KenyaTanzaniaMalawi_data (1).xlsx")

# %%
for idx, i in enumerate(spa['Indicator Value (Numeric)']):
    if i == 'Not in report':
        spa['Indicator Value (Numeric)'].iloc[idx] = np.nan
        spa['Indicator Value (Text)'].iloc[idx] = 'Not in report'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
for idx, i in enumerate(spa['Indicator Value (Numeric)']):
    if float(i) > 1:
        spa['Indicator Value (Numeric)'].iloc[idx] = float(i) / 100
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
spa
# Out:
#                                  Data Source   Country  Year  \
# 14824  DHS Service Provision Assesment (SPA)     Kenya  2010
# 14825  DHS Service Provision Assesment (SPA)    Malawi  2014
# 14826  DHS Service Provision Assesment (SPA)  Tanzania  2015
# 14827  DHS Service Provision Assesment (SPA)     Kenya  2010
# 14828  DHS Service Provision Assesment (SPA)    Malawi  2014
# 14829  DHS Service Provision Assesment (SPA)  Tanzania  2015
# 14830  DHS Service Provision Assesment (SPA)     Kenya  2010
# 14831  DHS Service Provision Assesment (SPA)    Malawi  2014
# 14832  DHS Service Provision Assesment (SPA)  Tanzania  2015
# 14833  DHS Service Provision Assesment (SPA)     Kenya  2010
# 14834  DHS Service Provision Assesment (SPA)    Malawi  2014
# 14835  DHS Service Provision Assesment (SPA)  Tanzania  2015
# 14836  DHS Service Provision Assesment (SPA)     Kenya  2010
# 14837  DHS Service Provision Assesment (SPA)     Kenya  2010
# ...

# %%
data = data[data['Data Source'] != 'DHS Service Provision Assesment (SPA)']

# %%
data = data.append(spa, ignore_index=True)

# %%
otherdhs_nepal = pd.read_excel("C:/Users/kusht/Downloads/125/DHS_Other Indicators_Bang_Nepal.xlsx")

# %%
nepal = otherdhs_nepal[otherdhs_nepal['Characteristic Category'] == 'Total']

# %%
nepal = nepal.drop(['Asset','Indicator definition'], axis=1)

# %%
otherdhs_bang = pd.read_excel("C:/Users/kusht/Downloads/125/DHS_Other Indicators_Bang_Nepal.xlsx", sheetname='Bangladesh')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
bang = otherdhs_bang[otherdhs_bang['Characteristic Category'] == 'Total']

# %%
bang = bang.drop(['Asset','Indicator definition'], axis=1)

# %%
data = data.append(nepal, ignore_index=True)

# %%
data = data.append(bang, ignore_index=True)

# %%
data[data['Country'] == 'Malawi']['Data Source'].unique()
# Out:
# array(['DHS', 'ENAP', 'HMIS', 'DHS Service Provision Assesment (SPA)'],
#       dtype=object)

# %%
mwother = data[(data['Country'] == 'Malawi')]

# %%
mwother = mwother[mwother['Data Source'] != 'HMIS']

# %%
mwhmis = pd.read_excel("C:/Users/kusht/Downloads/125/HMIS Malawi all requested DHIS2 indicators (1).xls", header=2)

# %%
mwhmis
# Out:
#    Period  NUT N Percentage of Low Birth Weight Babies  \
# 0    2019                                        0.072
# 1    2018                                        0.060
# 2    2017                                        0.095
# 3    2016                                        0.049
#
#    RHD Antenatal Care 1st Visit Before 13 Weeks Coverage  \
# 0                                              0.096
# 1                                              0.115
# 2                                              0.115
# 3                                              0.094
#
#    RHD N ANC 1 coverage (HMIS 15)  RHD N ANC 4th Visit Coverage  \
# 0                            0.02                         0.116
# 1                            0.14                         0.099
# 2                           12.40                         0.133
# 3                          114.30                         0.050
#
#    NUT N Percent pregnant women received 120+ FeFo tablets  \
# ...

# %%
mw2 = pd.melt(mwhmis, id_vars=['Period'], var_name='Indicator Name', value_name='Indicator Value (Numeric)')

# %%
mw2['Country'] = 'Malawi'
mw2['Data Source'] = 'HMIS'
mw2 = mw2.rename(columns={'Period':'Year'})
mw2['Characteristic Category'] = 'Total'
mw2['Characteristic Label'] = 'Total'
mw2['Indicator Value (Text)'] = np.nan

# %%
mw2
# Out:
#      Year                                     Indicator Name  \
# 0    2019        NUT N Percentage of Low Birth Weight Babies
# 1    2018        NUT N Percentage of Low Birth Weight Babies
# 2    2017        NUT N Percentage of Low Birth Weight Babies
# 3    2016        NUT N Percentage of Low Birth Weight Babies
# 4    2019  RHD Antenatal Care 1st Visit Before 13 Weeks C...
# 5    2018  RHD Antenatal Care 1st Visit Before 13 Weeks C...
# 6    2017  RHD Antenatal Care 1st Visit Before 13 Weeks C...
# 7    2016  RHD Antenatal Care 1st Visit Before 13 Weeks C...
# 8    2019                     RHD N ANC 1 coverage (HMIS 15)
# 9    2018                     RHD N ANC 1 coverage (HMIS 15)
# 10   2017                     RHD N ANC 1 coverage (HMIS 15)
# 11   2016                     RHD N ANC 1 coverage (HMIS 15)
# 12   2019                       RHD N ANC 4th Visit Coverage
# 13   2018                       RHD N ANC 4th Visit Coverage
# ...

# %%
mw = mwother.append(mw2, ignore_index=True)

# %%
data = data.append(mw, ignore_index=True)

# %%
ethmis = pd.read_excel("C:/Users/kusht/Downloads/125/HMIS Ethiopia.xlsx")

# %%
ethmis
# Out:
#   Source   Country                  Asset       Year  \
# 0   HMIS  Ethiopia                    KMC  2017-2018
# 1   HMIS  Ethiopia  Newborn Resuscitation  2017-2019
# 2   HMIS  Ethiopia        Iron-Folic Acid  2017-2020
#
#                               Milestone  \
# 0  6.8.2 - Population Coverage Achieved
# 1   6.8.3 - Effective Coverage Achieved
# 2   6.8.3 - Effective Coverage Achieved
#
#                               Indicator Name (match)  \
# 0  Proportion of low birth weight or premature ne...
# 1  Proportion of asphyxiated neonates who were re...
# 2  Proportion of pregnant women received iron and...
#
#                                 Indicator Definition  Indicator Value
# 0  Proportion of low birth weight or premature ne...            0.211
# 1  Proportion of asphyxiated neonates who were su...            0.832
# 2  Proportion of pregnant women attending at leas...            0.639

# %%
ethmis2 = pd.DataFrame(columns=['Data Source',
 'Country',
 'Year',
 'Characteristic Category',
 'Characteristic Label',
 'Indicator Name',
 'Indicator Value (Numeric)',
 'Indicator Value (Text)'])
ethmis2['Data Source'] = ethmis['Source']
ethmis2['Country'] = ethmis['Country']
ethmis2['Year'] = ethmis['Year']
ethmis2['Characteristic Category'] = 'Total'
ethmis2['Characteristic Label'] = 'Total'
ethmis2['Indicator Name'] = ethmis['Indicator Name (match)']
ethmis2['Indicator Value (Numeric)'] = ethmis['Indicator Value']
ethmis2['Indicator Value (Text)'] = np.nan

# %%
ethmis2
# Out:
#   Data Source   Country       Year Characteristic Category  \
# 0        HMIS  Ethiopia  2017-2018                   Total
# 1        HMIS  Ethiopia  2017-2019                   Total
# 2        HMIS  Ethiopia  2017-2020                   Total
#
#   Characteristic Label                                     Indicator Name  \
# 0                Total  Proportion of low birth weight or premature ne...
# 1                Total  Proportion of asphyxiated neonates who were re...
# 2                Total  Proportion of pregnant women received iron and...
#
#    Indicator Value (Numeric)  Indicator Value (Text)
# 0                      0.211                     NaN
# 1                      0.832                     NaN
# 2                      0.639                     NaN

# %%
data = data.append(ethmis2, ignore_index=True)
